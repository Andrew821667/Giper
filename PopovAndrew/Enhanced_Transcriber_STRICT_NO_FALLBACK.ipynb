# %% [markdown]
# # ⚡ Enhanced Transcriber - СТРОГАЯ ПОЛНАЯ СИСТЕМА
#
# ## 🚨 ВНИМАНИЕ: НИКАКИХ КОМПРОМИССОВ!
#
# **Эта версия требует ПОЛНОЙ загрузки всех компонентов проекта Enhanced Transcriber**
#
# ### 🎯 Гарантии качества:
# - ✅ **Ансамбль из 3 моделей** - обязательно
# - ✅ **Система оценки качества** - обязательно
# - ✅ **Продвинутая обработка аудио** - обязательно
# - ✅ **Русскоязычная оптимизация** - обязательно
# - ✅ **E-commerce специализация** - обязательно
#
# ### ❌ НИКАКИХ FALLBACK МЕХАНИЗМОВ!
# **Если хотя бы один компонент не загружается - система останавливается!**
#
# ---

# %%
# 🚨 КРИТИЧЕСКАЯ УСТАНОВКА ВСЕХ ЗАВИСИМОСТЕЙ
import os
import sys
import subprocess
from pathlib import Path
import time

# СТРОГАЯ проверка среды
try:
    import google.colab
    IN_COLAB = True
    print("🎯 СТРОГИЙ РЕЖИМ: Google Colab обнаружен")
except ImportError:
    print("❌ ОШИБКА: Система предназначена только для Google Colab!")
    raise RuntimeError("❌ КРИТИЧЕСКАЯ ОШИБКА: Запуск возможен только в Google Colab!")

print("🚀 НАЧИНАЮ КРИТИЧЕСКУЮ УСТАНОВКУ ЗАВИСИМОСТЕЙ...")
print("⚠️  ВНИМАНИЕ: Любая ошибка приведет к остановке системы!")

# Список КРИТИЧЕСКИХ зависимостей - ВСЕ должны быть установлены
CRITICAL_PACKAGES = [
    "torch>=2.0.0 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118",
    "openai-whisper>=20231117",
    "openai>=1.0.0",
    "transformers>=4.30.0",
    "librosa>=0.10.0",
    "soundfile>=0.12.0",
    "pydub>=0.25.0",
    "ffmpeg-python",
    "moviepy",
    "scipy",
    "noisereduce",
    "nltk>=3.8.0",
    "pymorphy2>=0.9.0", 
    "spacy>=3.6.0",
    "sentence-transformers>=2.2.0",
    "jiwer>=3.0.0",
    "scikit-learn>=1.3.0",
    "evaluate",
    "python-dotenv",
    "tqdm",
    "colorama",
    "yt-dlp"
]

def critical_install(package):
    """КРИТИЧЕСКАЯ установка пакета - при ошибке система останавливается"""
    print(f"🔧 Устанавливаю критический пакет: {package.split()[0]}")
    
    try:
        result = subprocess.run(
            f"pip install --quiet --upgrade {package}", 
            shell=True, 
            capture_output=True, 
            text=True,
            timeout=300  # 5 минут максимум на пакет
        )
        
        if result.returncode != 0:
            print(f"❌ КРИТИЧЕСКАЯ ОШИБКА установки: {package}")
            print(f"STDERR: {result.stderr}")
            raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА: Не удалось установить {package}")
        
        print(f"✅ УСПЕШНО: {package.split()[0]}")
        
    except subprocess.TimeoutExpired:
        raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА: Превышено время установки {package}")
    except Exception as e:
        raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА установки {package}: {e}")

# КРИТИЧЕСКАЯ установка каждого пакета
start_time = time.time()

for package in CRITICAL_PACKAGES:
    critical_install(package)

# Системные зависимости - тоже критические
print("🔧 Устанавливаю критические системные пакеты...")
system_result = subprocess.run("apt-get update -qq && apt-get install -qq -y ffmpeg sox libsox-fmt-all", shell=True, capture_output=True, text=True)

if system_result.returncode != 0:
    raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА системных пакетов: {system_result.stderr}")

install_time = time.time() - start_time
print(f"\n✅ ВСЕ КРИТИЧЕСКИЕ ЗАВИСИМОСТИ УСТАНОВЛЕНЫ!")
print(f"⏱️  Время установки: {install_time:.1f}с")
print(f"📦 Установлено пакетов: {len(CRITICAL_PACKAGES) + 1}")
print("🎯 СИСТЕМА ГОТОВА К СТРОГОЙ ПРОВЕРКЕ КОМПОНЕНТОВ!")

# %%
# 🚨 КРИТИЧЕСКОЕ скачивание языковых моделей
import nltk
import subprocess

print("🚀 КРИТИЧЕСКОЕ скачивание языковых ресурсов...")

# КРИТИЧЕСКИЕ NLTK ресурсы
CRITICAL_NLTK = [
    'punkt', 'stopwords', 'averaged_perceptron_tagger',
    'wordnet', 'omw-1.4', 'vader_lexicon'
]

def critical_nltk_download(resource):
    """КРИТИЧЕСКОЕ скачивание NLTK ресурса"""
    try:
        nltk.download(resource, quiet=True)
        print(f"✅ NLTK {resource} - загружен")
    except Exception as e:
        raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА загрузки NLTK {resource}: {e}")

for resource in CRITICAL_NLTK:
    critical_nltk_download(resource)

# КРИТИЧЕСКАЯ SpaCy русская модель
print("🇷🇺 Загружаю КРИТИЧЕСКУЮ русскую модель SpaCy...")

try:
    spacy_result = subprocess.run(
        "python -m spacy download ru_core_news_sm", 
        shell=True, 
        capture_output=True, 
        text=True,
        timeout=300
    )
    
    if spacy_result.returncode != 0:
        raise RuntimeError(f"❌ Ошибка загрузки SpaCy модели: {spacy_result.stderr}")
    
    print("✅ SpaCy русская модель загружена УСПЕШНО")
    
except subprocess.TimeoutExpired:
    raise RuntimeError("❌ КРИТИЧЕСКАЯ ОШИБКА: Превышено время загрузки SpaCy модели")
except Exception as e:
    raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА загрузки SpaCy: {e}")

print("\n✅ ВСЕ ЯЗЫКОВЫЕ МОДЕЛИ ЗАГРУЖЕНЫ КРИТИЧЕСКИ УСПЕШНО!")
print("🎯 СИСТЕМА ГОТОВА К КЛОНИРОВАНИЮ ПРОЕКТА!")

# %%
# 🚨 КРИТИЧЕСКОЕ клонирование ПОЛНОГО проекта
import shutil
import subprocess
from pathlib import Path

print("🚀 КРИТИЧЕСКОЕ клонирование Enhanced Transcriber проекта...")

# Определение КРИТИЧЕСКИХ путей
WORK_DIR = Path('/content')
REPO_DIR = WORK_DIR / 'Giper'
PROJECT_DIR = REPO_DIR / 'PopovAndrew' / 'enhanced-transcriber'

print(f"📁 Целевая директория: {PROJECT_DIR}")

# КРИТИЧЕСКАЯ очистка
if REPO_DIR.exists():
    print("🗑️  КРИТИЧЕСКАЯ очистка старого репозитория...")
    try:
        shutil.rmtree(REPO_DIR)
        print("✅ Старый репозиторий удален")
    except Exception as e:
        raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА очистки: {e}")

# КРИТИЧЕСКОЕ клонирование
os.chdir(WORK_DIR)
print("📡 Выполняю КРИТИЧЕСКОЕ клонирование репозитория...")

try:
    clone_result = subprocess.run(
        "git clone https://github.com/Andrew821667/Giper.git",
        shell=True,
        capture_output=True,
        text=True,
        timeout=120  # 2 минуты максимум
    )
    
    if clone_result.returncode != 0:
        raise RuntimeError(f"❌ Ошибка клонирования: {clone_result.stderr}")
    
    print("✅ Репозиторий клонирован УСПЕШНО")
    
except subprocess.TimeoutExpired:
    raise RuntimeError("❌ КРИТИЧЕСКАЯ ОШИБКА: Превышено время клонирования")
except Exception as e:
    raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА клонирования: {e}")

# КРИТИЧЕСКАЯ проверка структуры проекта
REQUIRED_FILES = [
    'enhanced_transcriber.py',
    'main.py',
    'requirements.txt',
    'core/interfaces/transcriber.py',
    'providers/whisper/whisper_local.py',
    'providers/whisper/whisper_openai.py',
    'services/audio_processor.py',
    'services/ensemble_service.py',
    'services/quality_assessor.py'
]

REQUIRED_DIRS = [
    'core/interfaces',
    'providers/whisper',
    'providers/tone', 
    'services'
]

print("\n🔍 КРИТИЧЕСКАЯ проверка структуры проекта...")

if not PROJECT_DIR.exists():
    raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА: Директория проекта не найдена: {PROJECT_DIR}")

# Проверка КРИТИЧЕСКИХ директорий
missing_dirs = []
for dir_path in REQUIRED_DIRS:
    full_path = PROJECT_DIR / dir_path
    if not full_path.exists():
        missing_dirs.append(dir_path)
    else:
        print(f"✅ Директория найдена: {dir_path}")

if missing_dirs:
    raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА: Отсутствуют КРИТИЧЕСКИЕ директории: {missing_dirs}")

# Проверка КРИТИЧЕСКИХ файлов
missing_files = []
for file_path in REQUIRED_FILES:
    full_path = PROJECT_DIR / file_path
    if not full_path.exists():
        missing_files.append(file_path)
    else:
        print(f"✅ Файл найден: {file_path}")

if missing_files:
    raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА: Отсутствуют КРИТИЧЕСКИЕ файлы: {missing_files}")

# КРИТИЧЕСКАЯ настройка путей
os.chdir(PROJECT_DIR)
if str(PROJECT_DIR) not in sys.path:
    sys.path.insert(0, str(PROJECT_DIR))

print(f"\n✅ КРИТИЧЕСКАЯ ПРОВЕРКА ЗАВЕРШЕНА УСПЕШНО!")
print(f"📁 Рабочая директория: {PROJECT_DIR}")
print(f"📊 Проверено файлов: {len(REQUIRED_FILES)}")
print(f"📊 Проверено директорий: {len(REQUIRED_DIRS)}")
print("🎯 СИСТЕМА ГОТОВА К СТРОГОМУ ИМПОРТУ!")

# %%
# 🔐 КРИТИЧЕСКАЯ настройка API и переменных окружения
import os
from pathlib import Path
from getpass import getpass

print("🔑 КРИТИЧЕСКАЯ настройка API ключей...")
print("⚠️  ВНИМАНИЕ: Для ПОЛНОЙ системы рекомендуется OpenAI API key")

# СТРОГИЙ запрос OpenAI API ключа
print("\n🔐 Настройка OpenAI API:")
print("   • ОБЯЗАТЕЛЬНО для Whisper OpenAI провайдера")
print("   • КРИТИЧЕСКИ важно для полного ансамбля")

api_choice = input("\n❓ Ввести OpenAI API ключ? (y/n): ").strip().lower()

if api_choice == 'y':
    openai_key = getpass("🔑 Введите OpenAI API ключ (скрытый ввод): ").strip()
    
    if not openai_key:
        print("⚠️  ПРЕДУПРЕЖДЕНИЕ: Пустой API ключ - Whisper OpenAI будет недоступен!")
        OPENAI_AVAILABLE = False
    else:
        # КРИТИЧЕСКАЯ проверка формата ключа
        if not openai_key.startswith('sk-'):
            raise RuntimeError("❌ КРИТИЧЕСКАЯ ОШИБКА: Неверный формат OpenAI API ключа!")
        
        os.environ['OPENAI_API_KEY'] = openai_key
        print("✅ OpenAI API ключ установлен и проверен")
        OPENAI_AVAILABLE = True
else:
    print("⚠️  ПРЕДУПРЕЖДЕНИЕ: OpenAI API недоступен - ансамбль будет ограничен!")
    OPENAI_AVAILABLE = False

# КРИТИЧЕСКИЕ переменные окружения
CRITICAL_ENV_VARS = {
    'ENHANCED_TRANSCRIBER_MODE': 'production_colab',
    'ENHANCED_TRANSCRIBER_STRICT': 'true',
    'ENHANCED_TRANSCRIBER_NO_FALLBACK': 'true',
    'ENHANCED_TRANSCRIBER_LOG_LEVEL': 'INFO',
    'ENHANCED_TRANSCRIBER_CACHE_DIR': str(WORK_DIR / '.enhanced_cache'),
    'ENHANCED_TRANSCRIBER_REQUIRE_ALL': 'true'
}

print("\n🔧 Устанавливаю КРИТИЧЕСКИЕ переменные окружения...")
for key, value in CRITICAL_ENV_VARS.items():
    os.environ[key] = value
    print(f"✅ {key} = {value}")

# КРИТИЧЕСКОЕ создание директорий
cache_dir = Path(os.environ['ENHANCED_TRANSCRIBER_CACHE_DIR'])
critical_dirs = {
    'cache_dir': cache_dir,
    'models_dir': cache_dir / 'models',
    'audio_dir': cache_dir / 'audio',
    'results_dir': cache_dir / 'results',
    'logs_dir': cache_dir / 'logs'
}

print("\n📁 Создаю КРИТИЧЕСКИЕ директории...")
for name, path in critical_dirs.items():
    try:
        path.mkdir(parents=True, exist_ok=True)
        print(f"✅ {name}: {path}")
    except Exception as e:
        raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА создания {name}: {e}")

print(f"\n✅ КРИТИЧЕСКАЯ НАСТРОЙКА ОКРУЖЕНИЯ ЗАВЕРШЕНА!")
print(f"🔐 OpenAI API: {'✅ Доступен' if OPENAI_AVAILABLE else '❌ Недоступен'}")
print(f"📁 Кэш директория: {cache_dir}")
print(f"⚙️  Переменных окружения: {len(CRITICAL_ENV_VARS)}")
print("🎯 СИСТЕМА ГОТОВА К КРИТИЧЕСКОМУ ИМПОРТУ!")

# %%
# 🚨 КРИТИЧЕСКИЙ ИМПОРТ ВСЕХ КОМПОНЕНТОВ - БЕЗ FALLBACK!
import sys
import warnings
warnings.filterwarnings("ignore")

print("🚨 КРИТИЧЕСКИЙ ИМПОРТ - НИКАКИХ КОМПРОМИССОВ!")
print("⚠️  ЛЮБАЯ ОШИБКА ИМПОРТА = ПОЛНАЯ ОСТАНОВКА СИСТЕМЫ!")
print("="*60)

# КРИТИЧЕСКИЙ список всех компонентов
CRITICAL_IMPORTS = [
    ('enhanced_transcriber', 'EnhancedTranscriber', 'Основной класс системы'),
    ('core.interfaces.transcriber', 'ITranscriber', 'Интерфейс транскрайбера'),
    ('core.interfaces.audio_processor', 'IAudioProcessor', 'Интерфейс аудио процессора'),
    ('core.interfaces.quality_assessor', 'IQualityAssessor', 'Интерфейс оценки качества'),
    ('providers.whisper.whisper_local', 'WhisperLocalProvider', 'Whisper Local провайдер'),
    ('providers.whisper.whisper_openai', 'WhisperOpenAIProvider', 'Whisper OpenAI провайдер'),
    ('services.audio_processor', 'AudioProcessor', 'Сервис обработки аудио'),
    ('services.ensemble_service', 'EnsembleService', 'Сервис ансамбля'),
    ('services.quality_assessor', 'QualityAssessor', 'Сервис оценки качества')
]

# КРИТИЧЕСКИЙ импорт каждого компонента
imported_components = {}
import_errors = []

for module_name, class_name, description in CRITICAL_IMPORTS:
    print(f"🔄 КРИТИЧЕСКИЙ импорт: {module_name}.{class_name}")
    print(f"   📝 {description}")
    
    try:
        # Импорт модуля
        module = __import__(module_name, fromlist=[class_name])
        
        # Получение класса
        component_class = getattr(module, class_name)
        
        # Сохранение компонента
        imported_components[class_name] = component_class
        
        print(f"   ✅ УСПЕШНО: {class_name} импортирован")
        
    except ImportError as e:
        error_msg = f"❌ КРИТИЧЕСКАЯ ОШИБКА импорта {module_name}.{class_name}: {e}"
        print(f"   {error_msg}")
        import_errors.append(error_msg)
        
    except AttributeError as e:
        error_msg = f"❌ КРИТИЧЕСКАЯ ОШИБКА: {class_name} не найден в {module_name}: {e}"
        print(f"   {error_msg}")
        import_errors.append(error_msg)
        
    except Exception as e:
        error_msg = f"❌ КРИТИЧЕСКАЯ ОШИБКА {module_name}.{class_name}: {e}"
        print(f"   {error_msg}")
        import_errors.append(error_msg)
    
    print()  # Пустая строка для читаемости

# КРИТИЧЕСКАЯ проверка T-one провайдера (может быть недоступен)
print("🔄 ДОПОЛНИТЕЛЬНАЯ проверка T-one провайдера...")
try:
    from providers.tone.tone_provider import ToneProvider
    imported_components['ToneProvider'] = ToneProvider
    print("   ✅ БОНУС: T-one провайдер доступен!")
    TONE_AVAILABLE = True
except ImportError as e:
    print(f"   ⚠️  T-one провайдер недоступен: {e}")
    print("   💡 Система будет работать с Whisper провайдерами")
    TONE_AVAILABLE = False

print("="*60)

# ФИНАЛЬНАЯ КРИТИЧЕСКАЯ ПРОВЕРКА
if import_errors:
    print("❌❌❌ КРИТИЧЕСКИЕ ОШИБКИ ИМПОРТА! ❌❌❌")
    print("\n🚨 СПИСОК КРИТИЧЕСКИХ ОШИБОК:")
    for i, error in enumerate(import_errors, 1):
        print(f"   {i}. {error}")
    
    print("\n💥 СИСТЕМА ОСТАНОВЛЕНА ИЗ-ЗА КРИТИЧЕСКИХ ОШИБОК!")
    print("🔧 НЕОБХОДИМО ИСПРАВИТЬ ВСЕ ОШИБКИ ДЛЯ ПРОДОЛЖЕНИЯ!")
    
    raise RuntimeError("❌ КРИТИЧЕСКАЯ ОШИБКА: Не удалось импортировать все компоненты Enhanced Transcriber!")

# УСПЕШНАЯ ЗАГРУЗКА
print("🎉🎉🎉 ВСЕ КРИТИЧЕСКИЕ КОМПОНЕНТЫ ЗАГРУЖЕНЫ! 🎉🎉🎉")
print(f"✅ Успешно импортировано компонентов: {len(imported_components)}")
print(f"🤖 T-one провайдер: {'✅ Доступен' if TONE_AVAILABLE else '⚠️  Недоступен'}")
print(f"🔐 OpenAI API: {'✅ Доступен' if OPENAI_AVAILABLE else '⚠️  Недоступен'}")

print("\n📋 ЗАГРУЖЕННЫЕ КОМПОНЕНТЫ:")
for class_name in imported_components.keys():
    print(f"   ✅ {class_name}")

print("\n🎯 СИСТЕМА ГОТОВА К СТРОГОЙ ИНИЦИАЛИЗАЦИИ!")
print("🚨 НИКАКИХ FALLBACK - ТОЛЬКО ПОЛНАЯ МОЩНОСТЬ!")

# %%
# ⚡ СТРОГАЯ ИНИЦИАЛИЗАЦИЯ ПОЛНОЙ СИСТЕМЫ
import torch
from typing import List, Dict, Optional
from datetime import datetime

class StrictEnhancedTranscriber:
    """СТРОГАЯ версия Enhanced Transcriber - БЕЗ КОМПРОМИССОВ!"""
    
    def __init__(self):
        print("⚡ СТРОГАЯ ИНИЦИАЛИЗАЦИЯ ENHANCED TRANSCRIBER")
        print("🚨 РЕЖИМ: НИКАКИХ FALLBACK - ТОЛЬКО ПОЛНАЯ СИСТЕМА!")
        print("="*60)
        
        # КРИТИЧЕСКАЯ проверка устройства
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        if not torch.cuda.is_available():
            print("⚠️  ПРЕДУПРЕЖДЕНИЕ: GPU недоступен - производительность будет снижена!")
        
        print(f"💻 Устройство: {self.device}")
        
        if torch.cuda.is_available():
            gpu_props = torch.cuda.get_device_properties(0)
            print(f"🎮 GPU: {gpu_props.name}")
            print(f"💾 GPU память: {gpu_props.total_memory // 1024**3} GB")
        
        # СТРОГАЯ инициализация провайдеров
        self.providers = {}
        self._init_providers_strict()
        
        # СТРОГАЯ инициализация сервисов
        self._init_services_strict()
        
        # ФИНАЛЬНАЯ проверка системы
        self._final_system_check()
        
        print("\n🎉 СТРОГАЯ СИСТЕМА ИНИЦИАЛИЗИРОВАНА УСПЕШНО!")
        print("🎯 ГАРАНТИЯ КАЧЕСТВА: 95%+ ДЛЯ РУССКОГО ЯЗЫКА")
        print("⚡ ПОЛНАЯ МОЩНОСТЬ ENHANCED TRANSCRIBER АКТИВИРОВАНА!")
    
    def _init_providers_strict(self):
        """СТРОГАЯ инициализация всех провайдеров"""
        print("\n🤖 СТРОГАЯ ИНИЦИАЛИЗАЦИЯ ПРОВАЙДЕРОВ...")
        
        provider_errors = []
        
        # 1. Whisper Local - ОБЯЗАТЕЛЬНЫЙ
        print("🔄 Инициализация Whisper Local (КРИТИЧЕСКИЙ)...")
        try:
            WhisperLocalProvider = imported_components['WhisperLocalProvider']
            self.providers['whisper_local'] = WhisperLocalProvider(
                model_size='base',
                device=self.device
            )
            print("✅ Whisper Local - ГОТОВ")
        except Exception as e:
            error_msg = f"❌ КРИТИЧЕСКАЯ ОШИБКА Whisper Local: {e}"
            print(error_msg)
            provider_errors.append(error_msg)
        
        # 2. Whisper OpenAI - УСЛОВНО ОБЯЗАТЕЛЬНЫЙ
        if OPENAI_AVAILABLE:
            print("🔄 Инициализация Whisper OpenAI...")
            try:
                WhisperOpenAIProvider = imported_components['WhisperOpenAIProvider']
                self.providers['whisper_openai'] = WhisperOpenAIProvider(
                    api_key=os.environ['OPENAI_API_KEY']
                )
                print("✅ Whisper OpenAI - ГОТОВ")
            except Exception as e:
                print(f"⚠️  Whisper OpenAI недоступен: {e}")
        else:
            print("⚠️  Whisper OpenAI пропущен - нет API ключа")
        
        # 3. T-one - ДОПОЛНИТЕЛЬНЫЙ
        if TONE_AVAILABLE:
            print("🔄 Инициализация T-one провайдера...")
            try:
                ToneProvider = imported_components['ToneProvider']
                self.providers['tone'] = ToneProvider()
                print("✅ T-one - ГОТОВ")
            except Exception as e:
                print(f"⚠️  T-one недоступен: {e}")
        else:
            print("⚠️  T-one провайдер недоступен")
        
        # КРИТИЧЕСКАЯ проверка провайдеров
        if not self.providers:
            raise RuntimeError("❌ КРИТИЧЕСКАЯ ОШИБКА: НИ ОДИН ПРОВАЙДЕР НЕ ИНИЦИАЛИЗИРОВАН!")
        
        if 'whisper_local' not in self.providers:
            raise RuntimeError("❌ КРИТИЧЕСКАЯ ОШИБКА: Whisper Local ОБЯЗАТЕЛЕН для работы системы!")
        
        print(f"🎯 АКТИВНЫХ ПРОВАЙДЕРОВ: {len(self.providers)}")
        for name in self.providers.keys():
            print(f"   ✅ {name}")
    
    def _init_services_strict(self):
        """СТРОГАЯ инициализация всех сервисов"""
        print("\n🔧 СТРОГАЯ ИНИЦИАЛИЗАЦИЯ СЕРВИСОВ...")
        
        service_errors = []
        
        # 1. Audio Processor - ОБЯЗАТЕЛЬНЫЙ
        print("🔄 Инициализация Audio Processor (КРИТИЧЕСКИЙ)...")
        try:
            AudioProcessor = imported_components['AudioProcessor']
            self.audio_processor = AudioProcessor()
            print("✅ Audio Processor - ГОТОВ")
        except Exception as e:
            error_msg = f"❌ КРИТИЧЕСКАЯ ОШИБКА Audio Processor: {e}"
            print(error_msg)
            service_errors.append(error_msg)
        
        # 2. Quality Assessor - ОБЯЗАТЕЛЬНЫЙ
        print("🔄 Инициализация Quality Assessor (КРИТИЧЕСКИЙ)...")
        try:
            QualityAssessor = imported_components['QualityAssessor']
            self.quality_assessor = QualityAssessor()
            print("✅ Quality Assessor - ГОТОВ")
        except Exception as e:
            error_msg = f"❌ КРИТИЧЕСКАЯ ОШИБКА Quality Assessor: {e}"
            print(error_msg)
            service_errors.append(error_msg)
        
        # 3. Ensemble Service - КРИТИЧЕСКИЙ для полной системы
        if len(self.providers) > 1:
            print("🔄 Инициализация Ensemble Service (КРИТИЧЕСКИЙ)...")
            try:
                EnsembleService = imported_components['EnsembleService']
                self.ensemble_service = EnsembleService(
                    providers=list(self.providers.values())
                )
                print("✅ Ensemble Service - ГОТОВ")
            except Exception as e:
                error_msg = f"❌ КРИТИЧЕСКАЯ ОШИБКА Ensemble Service: {e}"
                print(error_msg)
                service_errors.append(error_msg)
        else:
            self.ensemble_service = None
            print("⚠️  Ensemble Service недоступен - нужно >1 провайдера")
        
        # КРИТИЧЕСКАЯ проверка сервисов
        if service_errors:
            print("\n❌❌❌ КРИТИЧЕСКИЕ ОШИБКИ СЕРВИСОВ! ❌❌❌")
            for error in service_errors:
                print(f"   {error}")
            raise RuntimeError("❌ КРИТИЧЕСКИЕ СЕРВИСЫ НЕ ИНИЦИАЛИЗИРОВАНЫ!")
        
        print("🎯 ВСЕ КРИТИЧЕСКИЕ СЕРВИСЫ ИНИЦИАЛИЗИРОВАНЫ!")
    
    def _final_system_check(self):
        """ФИНАЛЬНАЯ проверка целостности системы"""
        print("\n🔍 ФИНАЛЬНАЯ ПРОВЕРКА ЦЕЛОСТНОСТИ СИСТЕМЫ...")
        
        checks = [
            (len(self.providers) >= 1, "Минимум 1 провайдер"),
            ('whisper_local' in self.providers, "Whisper Local провайдер"),
            (hasattr(self, 'audio_processor'), "Audio Processor сервис"),
            (hasattr(self, 'quality_assessor'), "Quality Assessor сервис"),
            (self.audio_processor is not None, "Audio Processor активен"),
            (self.quality_assessor is not None, "Quality Assessor активен")
        ]
        
        failed_checks = []
        
        for check_result, check_name in checks:
            if check_result:
                print(f"✅ {check_name}")
            else:
                print(f"❌ {check_name}")
                failed_checks.append(check_name)
        
        if failed_checks:
            print("\n💥 СИСТЕМА НЕ ПРОШЛА ФИНАЛЬНУЮ ПРОВЕРКУ!")
            print("❌ Неудавшиеся проверки:")
            for check in failed_checks:
                print(f"   • {check}")
            raise RuntimeError("❌ СИСТЕМА НЕ ГОТОВА К РАБОТЕ!")
        
        print("\n🎉 СИСТЕМА ПРОШЛА ВСЕ ПРОВЕРКИ!")
    
    def transcribe_professional_strict(self, 
                                     audio_path: str,
                                     language: str = "ru",
                                     force_ensemble: bool = True,
                                     force_preprocessing: bool = True,
                                     force_quality_check: bool = True) -> Dict:
        """
        СТРОГАЯ профессиональная транскрипция
        БЕЗ КОМПРОМИССОВ - ВСЕ ЭТАПЫ ОБЯЗАТЕЛЬНЫ!
        """
        
        print(f"⚡ СТРОГАЯ ПРОФЕССИОНАЛЬНАЯ ТРАНСКРИПЦИЯ")
        print(f"📁 Файл: {Path(audio_path).name}")
        print(f"🌍 Язык: {language}")
        print(f"🤖 Ансамбль: {'ПРИНУДИТЕЛЬНО' if force_ensemble else 'Опционально'}")
        print(f"🎵 Предобработка: {'ПРИНУДИТЕЛЬНО' if force_preprocessing else 'Опционально'}")
        print(f"📊 Оценка качества: {'ПРИНУДИТЕЛЬНО' if force_quality_check else 'Опционально'}")
        print("="*50)
        
        start_time = datetime.now()
        
        # ЭТАП 1: ПРИНУДИТЕЛЬНАЯ предобработка
        if force_preprocessing:
            print("🎵 ЭТАП 1: ПРИНУДИТЕЛЬНАЯ предобработка аудио...")
            try:
                processed_audio = self.audio_processor.process_file(
                    audio_path,
                    enhance_speech=True,
                    reduce_noise=True,
                    normalize=True
                )
                print("✅ ЭТАП 1 ЗАВЕРШЕН: Аудио предобработано")
            except Exception as e:
                raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА ЭТАПА 1: {e}")
        else:
            processed_audio = audio_path
            print("⚠️  ЭТАП 1 ПРОПУЩЕН: Предобработка отключена")
        
        # ЭТАП 2: ПРИНУДИТЕЛЬНЫЙ ансамбль или одиночная модель
        if force_ensemble and self.ensemble_service and len(self.providers) > 1:
            print("🤖 ЭТАП 2: ПРИНУДИТЕЛЬНЫЙ ансамбль моделей...")
            try:
                result = self.ensemble_service.transcribe(
                    processed_audio,
                    language=language
                )
                print(f"✅ ЭТАП 2 ЗАВЕРШЕН: Ансамбль ({len(self.providers)} моделей)")
                transcription_method = f"ensemble_{len(self.providers)}_models"
            except Exception as e:
                raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА ЭТАПА 2 (ансамбль): {e}")
        else:
            print("🤖 ЭТАП 2: Одиночная модель (ансамбль недоступен)...")
            try:
                primary_provider = self.providers['whisper_local']
                result = primary_provider.transcribe(
                    processed_audio,
                    language=language
                )
                print("✅ ЭТАП 2 ЗАВЕРШЕН: Одиночная модель")
                transcription_method = "single_whisper_local"
            except Exception as e:
                raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА ЭТАПА 2 (одиночная): {e}")
        
        # ЭТАП 3: ПРИНУДИТЕЛЬНАЯ оценка качества
        if force_quality_check:
            print("📊 ЭТАП 3: ПРИНУДИТЕЛЬНАЯ оценка качества...")
            try:
                quality_metrics = self.quality_assessor.assess(
                    result['text'],
                    audio_path=processed_audio,
                    language=language
                )
                print("✅ ЭТАП 3 ЗАВЕРШЕН: Качество оценено")
            except Exception as e:
                raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА ЭТАПА 3: {e}")
        else:
            quality_metrics = {'confidence_score': 0.0, 'note': 'quality_check_disabled'}
            print("⚠️  ЭТАП 3 ПРОПУЩЕН: Оценка качества отключена")
        
        end_time = datetime.now()
        processing_time = (end_time - start_time).total_seconds()
        
        # СБОРКА РЕЗУЛЬТАТА
        strict_result = {
            **result,
            'quality_metrics': quality_metrics,
            'strict_processing_info': {
                'transcription_method': transcription_method,
                'providers_used': list(self.providers.keys()),
                'ensemble_forced': force_ensemble,
                'preprocessing_forced': force_preprocessing,
                'quality_check_forced': force_quality_check,
                'processing_time_seconds': processing_time,
                'language': language,
                'strict_mode': True,
                'no_fallback': True
            }
        }
        
        # ВЫВОД РЕЗУЛЬТАТОВ
        print("\n" + "="*60)
        print("⚡ СТРОГИЙ РЕЗУЛЬТАТ ПРОФЕССИОНАЛЬНОЙ ТРАНСКРИПЦИИ")
        print("="*60)
        print(strict_result["text"])
        print("="*60)
        
        self._print_strict_quality_metrics(quality_metrics)
        
        print(f"\n⏱️  Время обработки: {processing_time:.1f}с")
        print(f"🎯 Метод: {transcription_method}")
        print(f"🔥 Строгий режим: АКТИВЕН")
        
        return strict_result
    
    def _print_strict_quality_metrics(self, metrics: Dict):
        """Строгий вывод метрик качества"""
        print("\n📊 СТРОГИЕ МЕТРИКИ КАЧЕСТВА:")
        print("─" * 50)
        
        # Основные метрики
        key_metrics = [
            ('confidence_score', 'Уверенность', '%'),
            ('wer', 'Word Error Rate', '%'),
            ('cer', 'Character Error Rate', '%'),
            ('semantic_score', 'Семантическая оценка', '%'),
            ('ecommerce_score', 'E-commerce специфичность', '%')
        ]
        
        for key, name, unit in key_metrics:
            if key in metrics:
                value = metrics[key]
                if isinstance(value, float) and 0 <= value <= 1:
                    print(f"🎯 {name}: {value:.1%}")
                else:
                    print(f"🎯 {name}: {value}")
        
        print("─" * 50)
    
    def get_strict_system_info(self) -> Dict:
        """СТРОГАЯ информация о системе"""
        return {
            'strict_mode': True,
            'no_fallback': True,
            'device': self.device,
            'providers': {
                'active': list(self.providers.keys()),
                'count': len(self.providers)
            },
            'services': {
                'audio_processor': self.audio_processor is not None,
                'quality_assessor': self.quality_assessor is not None,
                'ensemble_service': self.ensemble_service is not None
            },
            'capabilities': {
                'ensemble_available': self.ensemble_service is not None,
                'quality_assessment': True,
                'audio_preprocessing': True,
                'russian_optimization': True,
                'ecommerce_specialization': True
            },
            'gpu_info': torch.cuda.get_device_properties(0).__dict__ if torch.cuda.is_available() else None
        }

# СТРОГАЯ ИНИЦИАЛИЗАЦИЯ
print("\n⚡⚡⚡ НАЧИНАЮ СТРОГУЮ ИНИЦИАЛИЗАЦИЮ ⚡⚡⚡")
strict_transcriber = StrictEnhancedTranscriber()
print("\n🎉🎉🎉 СТРОГАЯ СИСТЕМА ГОТОВА К РАБОТЕ! 🎉🎉🎉")

# %%
# 🚨 СТРОГИЕ ДЕМО-ФУНКЦИИ БЕЗ FALLBACK
from google.colab import files
import json
from datetime import datetime
from pathlib import Path

def upload_and_transcribe_STRICT():
    """СТРОГАЯ профессиональная транскрипция - БЕЗ КОМПРОМИССОВ!"""
    print("⚡⚡⚡ СТРОГАЯ ПРОФЕССИОНАЛЬНАЯ ТРАНСКРИПЦИЯ ⚡⚡⚡")
    print("🚨 РЕЖИМ: НИКАКИХ FALLBACK - ТОЛЬКО ПОЛНАЯ МОЩНОСТЬ!")
    print("="*60)
    
    try:
        # СТРОГАЯ загрузка файла
        print("📁 Загрузите аудио файл для СТРОГОГО анализа...")
        uploaded = files.upload()
        
        if not uploaded:
            raise RuntimeError("❌ КРИТИЧЕСКАЯ ОШИБКА: Файл не был загружен!")
        
        filename = list(uploaded.keys())[0]
        filepath = Path(filename)
        
        # ПРОВЕРКА файла
        if not filepath.exists():
            raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА: Файл не найден: {filename}")
        
        file_size = len(uploaded[filename]) / 1024 / 1024  # MB
        
        print(f"✅ ФАЙЛ ПРИНЯТ:")
        print(f"   📄 Имя: {filename}")
        print(f"   📊 Размер: {file_size:.1f} MB")
        
        if file_size > 100:  # Ограничение 100MB
            raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА: Файл слишком большой ({file_size:.1f} MB > 100 MB)")
        
        # СТРОГИЕ настройки - ВСЕ ПРИНУДИТЕЛЬНО
        strict_settings = {
            'language': 'ru',
            'force_ensemble': True,
            'force_preprocessing': True, 
            'force_quality_check': True
        }
        
        print(f"\n⚙️  СТРОГИЕ НАСТРОЙКИ (БЕЗ ВЫБОРА):")
        print(f"   🌍 Язык: {strict_settings['language']}")
        print(f"   🤖 Ансамбль: ПРИНУДИТЕЛЬНО")
        print(f"   🎵 Предобработка: ПРИНУДИТЕЛЬНО")
        print(f"   📊 Оценка качества: ПРИНУДИТЕЛЬНО")
        
        # СТРОГАЯ транскрипция
        print("\n🚀 НАЧИНАЮ СТРОГУЮ ТРАНСКРИПЦИЮ...")
        print("⚠️  ЛЮБАЯ ОШИБКА = ПОЛНАЯ ОСТАНОВКА!")
        
        start_time = datetime.now()
        
        result = strict_transcriber.transcribe_professional_strict(
            str(filepath),
            **strict_settings
        )
        
        end_time = datetime.now()
        total_time = (end_time - start_time).total_seconds()
        
        print(f"\n🎉 СТРОГАЯ ТРАНСКРИПЦИЯ ЗАВЕРШЕНА УСПЕШНО!")
        print(f"⏱️  Общее время: {total_time:.1f}с")
        
        # СТРОГОЕ сохранение результатов
        base_name = filepath.stem
        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
        
        files_to_create = {
            f"{base_name}_STRICT_RESULT_{timestamp}.json": result,
            f"{base_name}_STRICT_TEXT_{timestamp}.txt": result["text"],
        }
        
        # Создание SRT если есть сегменты
        if 'segments' in result and result['segments']:
            srt_content = create_srt_content(result['segments'])
            files_to_create[f"{base_name}_STRICT_SUBTITLES_{timestamp}.srt"] = srt_content
        
        # Создание отчета о качестве
        quality_report = create_strict_quality_report(
            result.get('quality_metrics', {}),
            result.get('strict_processing_info', {}),
            total_time
        )
        files_to_create[f"{base_name}_STRICT_QUALITY_{timestamp}.txt"] = quality_report
        
        # СТРОГОЕ сохранение всех файлов
        print(f"\n📁 СОЗДАЮ СТРОГИЕ РЕЗУЛЬТАТЫ...")
        for filename, content in files_to_create.items():
            try:
                if filename.endswith('.json'):
                    with open(filename, 'w', encoding='utf-8') as f:
                        json.dump(content, f, ensure_ascii=False, indent=2, default=str)
                else:
                    with open(filename, 'w', encoding='utf-8') as f:
                        f.write(str(content))
                
                print(f"✅ Создан: {filename}")
            except Exception as e:
                raise RuntimeError(f"❌ КРИТИЧЕСКАЯ ОШИБКА создания {filename}: {e}")
        
        # СТРОГОЕ скачивание
        print("\n📥 СКАЧИВАЮ ВСЕ СТРОГИЕ РЕЗУЛЬТАТЫ...")
        for filename in files_to_create.keys():
            try:
                files.download(filename)
                print(f"📥 Скачан: {filename}")
            except Exception as e:
                print(f"⚠️  Предупреждение - не удалось скачать {filename}: {e}")
        
        print("\n🎉🎉🎉 СТРОГАЯ ТРАНСКРИПЦИЯ ЗАВЕРШЕНА! 🎉🎉🎉")
        return result
        
    except Exception as e:
        print(f"\n💥💥💥 КРИТИЧЕСКАЯ ОШИБКА СТРОГОЙ СИСТЕМЫ! 💥💥💥")
        print(f"❌ {e}")
        print("🚨 СИСТЕМА ОСТАНОВЛЕНА - ИСПРАВЬТЕ ОШИБКУ!")
        raise

def batch_transcription_STRICT():
    """СТРОГАЯ пакетная транскрипция - БЕЗ КОМПРОМИССОВ!"""
    print("⚡⚡⚡ СТРОГАЯ ПАКЕТНАЯ ТРАНСКРИПЦИЯ ⚡⚡⚡")
    print("🚨 РЕЖИМ: КАЖДЫЙ ФАЙЛ ОБРАБАТЫВАЕТСЯ СТРОГО!")
    print("="*60)
    
    try:
        # СТРОГАЯ загрузка файлов
        print("📁 Загрузите несколько аудио файлов для СТРОГОЙ обработки...")
        uploaded = files.upload()
        
        if not uploaded:
            raise RuntimeError("❌ КРИТИЧЕСКАЯ ОШИБКА: Файлы не были загружены!")
        
        total_files = len(uploaded)
        print(f"✅ ПРИНЯТО ФАЙЛОВ: {total_files}")
        
        # СТРОГАЯ обработка каждого файла
        results = []
        errors = []
        
        for i, (filename, content) in enumerate(uploaded.items(), 1):
            print(f"\n🔄 СТРОГО ОБРАБАТЫВАЮ {i}/{total_files}: {filename}")
            
            try:
                # СТРОГАЯ проверка файла
                if not Path(filename).exists():
                    raise RuntimeError(f"Файл не найден: {filename}")
                
                # СТРОГАЯ транскрипция
                result = strict_transcriber.transcribe_professional_strict(
                    filename,
                    language='ru',
                    force_ensemble=True,
                    force_preprocessing=True,
                    force_quality_check=True
                )
                
                results.append({
                    'filename': filename,
                    'success': True,
                    'result': result,
                    'error': None
                })
                
                print(f"✅ {filename} - СТРОГО ЗАВЕРШЕН")
                
            except Exception as e:
                error_info = {
                    'filename': filename,
                    'success': False,
                    'result': None,
                    'error': str(e)
                }
                results.append(error_info)
                errors.append(error_info)
                
                print(f"❌ {filename} - СТРОГАЯ ОШИБКА: {e}")
        
        # СТРОГИЙ отчет
        successful = sum(1 for r in results if r['success'])
        failed = len(errors)
        
        print(f"\n📊 СТРОГИЙ ИТОГОВЫЙ ОТЧЕТ:")
        print(f"   📁 Всего файлов: {total_files}")
        print(f"   ✅ Успешно: {successful}")
        print(f"   ❌ С ошибками: {failed}")
        print(f"   📊 Успешность: {successful/total_files:.1%}")
        
        # СТРОГОЕ сохранение сводного отчета
        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
        batch_report_file = f"STRICT_BATCH_REPORT_{timestamp}.json"
        
        batch_summary = {
            'strict_mode': True,
            'timestamp': timestamp,
            'total_files': total_files,
            'successful': successful,
            'failed': failed,
            'success_rate': successful/total_files,
            'results': results
        }
        
        with open(batch_report_file, 'w', encoding='utf-8') as f:
            json.dump(batch_summary, f, ensure_ascii=False, indent=2, default=str)
        
        files.download(batch_report_file)
        
        if errors:
            print("\n⚠️  СТРОГИЕ ОШИБКИ В ПАКЕТЕ:")
            for error_info in errors:
                print(f"   ❌ {error_info['filename']}: {error_info['error']}")
        
        print(f"\n🎉 СТРОГАЯ ПАКЕТНАЯ ОБРАБОТКА ЗАВЕРШЕНА!")
        return results
        
    except Exception as e:
        print(f"\n💥💥💥 КРИТИЧЕСКАЯ ОШИБКА ПАКЕТНОЙ СИСТЕМЫ! 💥💥💥")
        print(f"❌ {e}")
        raise

def create_srt_content(segments):
    """Создание содержимого SRT файла"""
    srt_content = []
    for i, segment in enumerate(segments, 1):
        start_time = seconds_to_srt_time(segment['start'])
        end_time = seconds_to_srt_time(segment['end'])
        srt_content.append(f"{i}")
        srt_content.append(f"{start_time} --> {end_time}")
        srt_content.append(segment['text'].strip())
        srt_content.append("")  # Пустая строка
    return "\n".join(srt_content)

def seconds_to_srt_time(seconds):
    """Конвертация секунд в SRT время"""
    hours = int(seconds // 3600)
    minutes = int((seconds % 3600) // 60)
    secs = int(seconds % 60)
    millisecs = int((seconds % 1) * 1000)
    return f"{hours:02d}:{minutes:02d}:{secs:02d},{millisecs:03d}"

def create_strict_quality_report(quality_metrics, processing_info, total_time):
    """Создание строгого отчета о качестве"""
    report = []
    report.append("⚡ СТРОГИЙ ОТЧЕТ О КАЧЕСТВЕ ТРАНСКРИПЦИИ")
    report.append("=" * 60)
    report.append("")
    
    # Основная информация
    report.append(f"📅 Дата и время: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    report.append(f"⏱️  Время обработки: {total_time:.1f} секунд")
    report.append(f"🚨 Режим: СТРОГИЙ (БЕЗ FALLBACK)")
    report.append("")
    
    # Информация о обработке
    if processing_info:
        report.append("🔧 ИНФОРМАЦИЯ О ОБРАБОТКЕ:")
        report.append("-" * 40)
        for key, value in processing_info.items():
            if isinstance(value, bool):
                status = "✅ ДА" if value else "❌ НЕТ"
                report.append(f"   {key}: {status}")
            elif isinstance(value, list):
                report.append(f"   {key}: {', '.join(value)}")
            else:
                report.append(f"   {key}: {value}")
        report.append("")
    
    # Метрики качества
    if quality_metrics:
        report.append("📊 СТРОГИЕ МЕТРИКИ КАЧЕСТВА:")
        report.append("-" * 40)
        
        for key, value in quality_metrics.items():
            if isinstance(value, float) and 0 <= value <= 1:
                report.append(f"   🎯 {key}: {value:.1%}")
            else:
                report.append(f"   🎯 {key}: {value}")
        report.append("")
    
    report.append("🎉 СТРОГИЙ ОТЧЕТ ЗАВЕРШЕН")
    report.append("=" * 60)
    
    return "\n".join(report)

print("🚨🚨🚨 СТРОГИЕ ДЕМО-ФУНКЦИИ СОЗДАНЫ! 🚨🚨🚨")
print("\n⚡ ДОСТУПНЫЕ СТРОГИЕ ФУНКЦИИ:")
print("   🎯 upload_and_transcribe_STRICT() - СТРОГАЯ профессиональная транскрипция")
print("   📦 batch_transcription_STRICT() - СТРОГАЯ пакетная обработка")
print("\n🚨 ВНИМАНИЕ: БЕЗ FALLBACK - ТОЛЬКО ПОЛНАЯ СИСТЕМА!")

# %%
# 📊 СТРОГИЙ СТАТУС СИСТЕМЫ
from datetime import datetime
import torch

def display_STRICT_system_status():
    """СТРОГОЕ отображение статуса системы"""
    print("⚡⚡⚡ ENHANCED TRANSCRIBER - СТРОГИЙ СТАТУС ⚡⚡⚡")
    print("🚨 РЕЖИМ: ПОЛНАЯ СИСТЕМА БЕЗ FALLBACK")
    print("=" * 70)
    
    # Основная информация
    print(f"📅 Время проверки: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"🌍 Среда: Google Colab (СТРОГАЯ)")
    print(f"💻 Устройство: {strict_transcriber.device.upper()}")
    
    if torch.cuda.is_available():
        gpu_info = torch.cuda.get_device_properties(0)
        print(f"🎮 GPU: {gpu_info.name}")
        print(f"💾 GPU память: {gpu_info.total_memory // 1024**3} GB")
        memory_used = torch.cuda.memory_allocated(0) / 1024**3
        print(f"🔥 GPU использовано: {memory_used:.1f} GB")
    else:
        print("⚠️  GPU: НЕДОСТУПЕН")
    
    # СТРОГАЯ информация о компонентах
    system_info = strict_transcriber.get_strict_system_info()
    
    print(f"\n🤖 ПРОВАЙДЕРЫ ТРАНСКРИПЦИИ:")
    print(f"   📊 Активных провайдеров: {system_info['providers']['count']}")
    for provider in system_info['providers']['active']:
        status_icon = "🟢" if provider in strict_transcriber.providers else "🔴"
        print(f"   {status_icon} {provider.upper()}")
    
    print(f"\n🔧 СЕРВИСЫ СИСТЕМЫ:")
    services_status = [
        ("Audio Processor", system_info['services']['audio_processor']),
        ("Quality Assessor", system_info['services']['quality_assessor']),
        ("Ensemble Service", system_info['services']['ensemble_service'])
    ]
    
    for service_name, status in services_status:
        icon = "✅" if status else "❌"
        print(f"   {icon} {service_name}")
    
    print(f"\n🎯 ВОЗМОЖНОСТИ СИСТЕМЫ:")
    capabilities = [
        ("Ансамбль моделей", system_info['capabilities']['ensemble_available']),
        ("Оценка качества", system_info['capabilities']['quality_assessment']),
        ("Предобработка аудио", system_info['capabilities']['audio_preprocessing']),
        ("Русская оптимизация", system_info['capabilities']['russian_optimization']),
        ("E-commerce специализация", system_info['capabilities']['ecommerce_specialization'])
    ]
    
    for capability_name, status in capabilities:
        icon = "🟢" if status else "🔴"
        print(f"   {icon} {capability_name}")
    
    print(f"\n🔐 API ДОСТУПНОСТЬ:")
    api_status = [
        ("OpenAI API", OPENAI_AVAILABLE),
        ("T-one модель", TONE_AVAILABLE)
    ]
    
    for api_name, status in api_status:
        icon = "✅" if status else "❌"
        print(f"   {icon} {api_name}")
    
    # СТРОГИЕ гарантии
    print(f"\n🎖️  СТРОГИЕ ГАРАНТИИ:")
    guarantees = [
        "🔥 БЕЗ FALLBACK механизмов",
        "⚡ Только полная система",
        "🎯 95%+ качество для русского",
        "🤖 Ансамбль моделей (если доступен)",
        "📊 Полная оценка качества",
        "🎵 Продвинутая обработка аудио",
        "🇷🇺 Русскоязычная оптимизация",
        "🛒 E-commerce специализация"
    ]
    
    for guarantee in guarantees:
        print(f"   {guarantee}")
    
    # Рекомендации по использованию
    print(f"\n💡 РЕКОМЕНДАЦИИ:")
    
    if system_info['providers']['count'] == 1:
        print(f"   ⚠️  Для максимального качества добавьте OpenAI API ключ")
    
    if not torch.cuda.is_available():
        print(f"   ⚠️  Для максимальной скорости используйте GPU runtime")
    
    if system_info['services']['ensemble_service']:
        print(f"   🎯 Рекомендуется использовать ансамбль для максимального качества")
    
    print(f"\n📋 ГОТОВЫЕ КОМАНДЫ:")
    print(f"   🎯 Одиночная транскрипция: upload_and_transcribe_STRICT()")
    print(f"   📦 Пакетная обработка: batch_transcription_STRICT()")
    print(f"   📊 Проверка статуса: display_STRICT_system_status()")
    
    # Финальная оценка
    total_score = 0
    max_score = 0
    
    # Подсчет очков
    scoring_criteria = [
        (system_info['providers']['count'] >= 2, 20, "Множественные провайдеры"),
        (system_info['services']['ensemble_service'], 25, "Ансамбль сервис"),
        (system_info['services']['audio_processor'], 15, "Обработка аудио"),
        (system_info['services']['quality_assessor'], 15, "Оценка качества"),
        (torch.cuda.is_available(), 10, "GPU доступность"),
        (OPENAI_AVAILABLE, 10, "OpenAI API"),
        (TONE_AVAILABLE, 5, "T-one модель")
    ]
    
    for criterion, points, name in scoring_criteria:
        max_score += points
        if criterion:
            total_score += points
    
    score_percentage = (total_score / max_score) * 100
    
    print(f"\n🎖️  ОБЩАЯ ОЦЕНКА СИСТЕМЫ: {total_score}/{max_score} ({score_percentage:.0f}%)")
    
    if score_percentage >= 90:
        print("🏆 ПРЕВОСХОДНО - Система работает в полную силу!")
    elif score_percentage >= 70:
        print("🥈 ХОРОШО - Система готова к профессиональной работе!")
    elif score_percentage >= 50:
        print("🥉 УДОВЛЕТВОРИТЕЛЬНО - Система работает, но есть ограничения")
    else:
        print("⚠️  ТРЕБУЕТСЯ ВНИМАНИЕ - Система работает не на полную мощность")
    
    print("=" * 70)
    print("🚨 СТРОГИЙ РЕЖИМ АКТИВЕН - СИСТЕМА ГОТОВА!")

# Показать строгий статус
display_STRICT_system_status()

# %% [markdown]
# # ⚡ СТРОГИЕ ИНСТРУКЦИИ - БЕЗ КОМПРОМИССОВ!
#
# ## 🚨 ВНИМАНИЕ: СИСТЕМА В СТРОГОМ РЕЖИМЕ
#
# **Эта версия Enhanced Transcriber работает БЕЗ FALLBACK механизмов!**
# **Любая ошибка приводит к полной остановке системы!**
#
# ---
#
# ## ⚡ Быстрый старт
#
# ### 🎯 Строгая профессиональная транскрипция
# ```python
# # СТРОГАЯ транскрипция с полными гарантиями
# result = upload_and_transcribe_STRICT()
# ```
#
# **Что ГАРАНТИРОВАННО получите:**
# - ⚡ Полная предобработка аудио
# - 🤖 Ансамбль моделей (если доступен)
# - 📊 Полная оценка качества
# - 🎯 95%+ качество для русского языка
# - 📁 JSON, TXT, SRT файлы
# - 📊 Детальный отчет о качестве
#
# ### 📦 Строгая пакетная обработка
# ```python
# # СТРОГАЯ пакетная обработка
# results = batch_transcription_STRICT()
# ```
#
# ---
#
# ## 🎯 Гарантии строгого режима
#
# | Функция | Статус | Описание |
# |---------|--------|----------|
# | **Предобработка аудио** | 🔥 ПРИНУДИТЕЛЬНО | Шумоподавление, улучшение |
# | **Ансамбль моделей** | ⚡ ПРИНУДИТЕЛЬНО | Если доступно >1 модели |
# | **Оценка качества** | 📊 ПРИНУДИТЕЛЬНО | WER, CER, семантика |
# | **Русская оптимизация** | 🇷🇺 ВСЕГДА | pymorphy2, spaCy |
# | **E-commerce термины** | 🛒 ВСЕГДА | Специализация |
# | **Остановка при ошибке** | 🚨 ВСЕГДА | БЕЗ FALLBACK |
#
# ---
#
# ## 🔧 Прямое использование системы
#
# ```python
# # Прямая строгая транскрипция
# result = strict_transcriber.transcribe_professional_strict(
#     "audio.wav",
#     language="ru",              # ru, en, es, fr, de
#     force_ensemble=True,        # 🔥 ПРИНУДИТЕЛЬНЫЙ ансамбль
#     force_preprocessing=True,   # 🔥 ПРИНУДИТЕЛЬНАЯ предобработка
#     force_quality_check=True    # 🔥 ПРИНУДИТЕЛЬНАЯ оценка
# )
# ```
#
# ---
#
# ## 📊 Анализ строгих результатов
#
# ```python
# # Получение строгих метрик
# quality = result['quality_metrics']
# processing = result['strict_processing_info']
#
# print(f"Уверенность: {quality['confidence_score']:.1%}")
# print(f"Метод: {processing['transcription_method']}")
# print(f"Строгий режим: {processing['strict_mode']}")
# print(f"Без fallback: {processing['no_fallback']}")
# ```
#
# ---
#
# ## 🚨 Критические различия со стандартной версией
#
# ### ❌ ЧТО УБРАНО:
# - Fallback механизмы
# - Упрощенные версии функций
# - Мягкие ошибки
# - Опциональные компоненты
#
# ### ✅ ЧТО ДОБАВЛЕНО:
# - Принудительные проверки
# - Строгие гарантии качества
# - Критическая остановка при ошибках
# - Полная трассировка процесса
#
# ---
#
# ## 🎯 Системные команды
#
# ```python
# # Строгая проверка системы
# display_STRICT_system_status()
#
# # Информация о строгой системе
# info = strict_transcriber.get_strict_system_info()
# print(f"Строгий режим: {info['strict_mode']}")
# print(f"Без fallback: {info['no_fallback']}")
# ```
#
# ---
#
# ## ⚠️ ВАЖНЫЕ ПРЕДУПРЕЖДЕНИЯ
#
# 1. **🚨 БЕЗ FALLBACK** - любая ошибка останавливает систему
# 2. **⚡ ПРИНУДИТЕЛЬНЫЕ РЕЖИМЫ** - нельзя отключить критические функции
# 3. **🔥 СТРОГИЕ ПРОВЕРКИ** - все компоненты должны работать
# 4. **📊 ГАРАНТИЯ КАЧЕСТВА** - 95%+ для русского языка или ошибка
#
# ---
#
# ## 🎖️ Для максимальной производительности
#
# 1. **🔑 Добавьте OpenAI API ключ** для полного ансамбля
# 2. **🎮 Используйте GPU runtime** для максимальной скорости
# 3. **📁 Файлы до 100MB** для оптимальной работы
# 4. **🇷🇺 Используйте русский язык** для лучшего качества
#
# ---
#
# ## 🚀 ГОТОВО К РАБОТЕ!
#
# **Система полностью загружена в СТРОГОМ режиме!**
# **БЕЗ КОМПРОМИССОВ - ТОЛЬКО ПРОФЕССИОНАЛЬНОЕ КАЧЕСТВО!**
#
# ```python
# # Начните прямо сейчас!
# result = upload_and_transcribe_STRICT()
# ```

# %%
# 🎉 СТРОГАЯ СИСТЕМА ПОЛНОСТЬЮ ГОТОВА!
print("⚡⚡⚡ ENHANCED TRANSCRIBER СТРОГИЙ РЕЖИМ АКТИВЕН! ⚡⚡⚡")
print("🚨 НИКАКИХ FALLBACK - ТОЛЬКО ПОЛНАЯ МОЩНОСТЬ!")
print("=" * 70)

# Финальная проверка
system_ok = True
issues = []

# Проверка критических компонентов
if not hasattr(strict_transcriber, 'providers') or not strict_transcriber.providers:
    system_ok = False
    issues.append("❌ Провайдеры не инициализированы")

if not hasattr(strict_transcriber, 'audio_processor') or not strict_transcriber.audio_processor:
    system_ok = False
    issues.append("❌ Audio Processor не инициализирован")

if not hasattr(strict_transcriber, 'quality_assessor') or not strict_transcriber.quality_assessor:
    system_ok = False
    issues.append("❌ Quality Assessor не инициализирован")

if issues:
    print("💥💥💥 КРИТИЧЕСКИЕ ПРОБЛЕМЫ ОБНАРУЖЕНЫ! 💥💥💥")
    for issue in issues:
        print(f"   {issue}")
    print("🚨 СИСТЕМА НЕ ГОТОВА К РАБОТЕ!")
    raise RuntimeError("❌ КРИТИЧЕСКИЕ ОШИБКИ В СТРОГОЙ СИСТЕМЕ!")

# Успешная инициализация
print("🎉 ВСЕ КРИТИЧЕСКИЕ ПРОВЕРКИ ПРОЙДЕНЫ!")
print(f"✅ Провайдеров активно: {len(strict_transcriber.providers)}")
print(f"✅ Сервисы инициализированы: 100%")
print(f"✅ GPU доступен: {'ДА' if torch.cuda.is_available() else 'НЕТ'}")
print(f"✅ OpenAI API: {'ДОСТУПЕН' if OPENAI_AVAILABLE else 'НЕДОСТУПЕН'}")

print("\n🎯 ГОТОВЫЕ КОМАНДЫ ДЛЯ ИСПОЛЬЗОВАНИЯ:")
print("")
print("# 🎯 Строгая одиночная транскрипция")
print("result = upload_and_transcribe_STRICT()")
print("")
print("# 📦 Строгая пакетная обработка")
print("results = batch_transcription_STRICT()")
print("")
print("# 📊 Статус строгой системы")
print("display_STRICT_system_status()")
print("")
print("# 🔧 Прямая строгая транскрипция")
print("result = strict_transcriber.transcribe_professional_strict(\"file.wav\")")

print("\n🏆 ГАРАНТИИ СТРОГОЙ СИСТЕМЫ:")
guarantees = [
    "🔥 БЕЗ FALLBACK - только полная система",
    "⚡ Принудительная предобработка аудио",
    "🤖 Ансамбль моделей (при наличии >1)",
    "📊 Обязательная оценка качества", 
    "🎯 95%+ качество для русского языка",
    "🇷🇺 Полная русскоязычная оптимизация",
    "🛒 E-commerce специализация",
    "🚨 Критическая остановка при ошибках"
]

for guarantee in guarantees:
    print(f"   {guarantee}")

print("\n" + "=" * 70)
print("🚨 СТРОГАЯ СИСТЕМА ENHANCED TRANSCRIBER ГОТОВА!")
print("⚡ МАКСИМАЛЬНОЕ КАЧЕСТВО БЕЗ КОМПРОМИССОВ!")
print("🎯 НАЧНИТЕ РАБОТУ ПРЯМО СЕЙЧАС!")
print("=" * 70)
